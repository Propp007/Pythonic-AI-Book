# %% [markdown]
# <a href="https://colab.research.google.com/github/Propp007/Pythonic-AI-Book/blob/main/ImageClassifireApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
im = Image.open("./test.jpg")
im = np.array(im)
im = im/255.0
print(im.shape)
plt.imshow(im)
# Out:
# (32, 32, 3)
